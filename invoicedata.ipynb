# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/priap/Downloads/invoices.csv')

# %%
df.head()
# Out:
#             first_name      last_name                      email  product_id  \
# 0         Carmen Nixon  Todd Anderson  marvinjackson@example.com         133
# 1  Mrs. Heather Miller    Julia Moore      jeffrey84@example.net         155
# 2          Crystal May   Philip Moody       ugoodman@example.com         151
# 3          Bobby Weber     Mark Scott       ssanchez@example.com         143
# 4        Kristen Welch    David David      cynthia66@example.net         168
#
#    qty  amount invoice_date                          address            city  \
# 0    9   14.57   10/09/1982                 283 Wendy Common  West Alexander
# 1    5   65.48   03/10/2012  13567 Patricia Circles Apt. 751     Andreamouth
# 2    9   24.66   23/03/1976     6389 Debbie Island Suite 470         Coxbury
# 3    4   21.34   17/08/1986       6362 Ashley Plaza Apt. 994        Ninaland
# 4    2   83.90   11/06/1996      463 Steven Cliffs Suite 757      Isaiahview
#
# ...

# %% [markdown]
# #Cleaning , preparing data

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    10000 non-null  object
#  1   last_name     10000 non-null  object
#  2   email         10000 non-null  object
#  3   product_id    10000 non-null  int64
#  4   qty           10000 non-null  int64
#  5   amount        10000 non-null  float64
#  6   invoice_date  10000 non-null  object
#  7   address       10000 non-null  object
#  8   city          10000 non-null  object
#  9   stock_code    10000 non-null  int64
#  10  job           10000 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 859.5+ KB
# None

# %%
print(df.columns)
# Out:
# Index(['first_name', 'last_name', 'email', 'product_id', 'qty', 'amount',
#        'invoice_date', 'address', 'city', 'stock_code', 'job'],
#       dtype='object')

# %%
print(df.describe())
# Out:
#          product_id           qty        amount    stock_code
# count  10000.000000  10000.000000  10000.000000  1.000000e+04
# mean     149.746700      5.005900     52.918236  4.950036e+07
# std       28.728186      2.576767     27.434579  2.903081e+07
# min      100.000000      1.000000      5.010000  1.977000e+03
# 25%      125.000000      3.000000     29.137500  2.425234e+07
# 50%      150.000000      5.000000     53.485000  4.931714e+07
# 75%      175.000000      7.000000     76.520000  7.457446e+07
# max      199.000000      9.000000     99.990000  9.999216e+07

# %%
total_sales=df["amount"].sum()
print("Total sales:" , total_sales)
# Out:
# Total sales: 529182.36

# %%
avg_qty=df["qty"].mean()
print("Average qty:", avg_qty)
# Out:
# Average qty: 5.0059

# %%
city_sales=df.groupby("city")["amount"].sum()
print("City sales:", city_sales)
# Out:
# City sales: city
# Aaronburgh           92.59
# Aaronfurt            98.36
# Aaronland            32.78
# Aaronport            80.11
# Aaronshire          158.12
#                      ...
# Zacharyville         81.10
# Zavalafort           42.84
# Zhangton             34.23
# Zimmermanberg        58.39
# Zimmermanchester     59.99
# Name: amount, Length: 7773, dtype: float64

# %%
max_sales=df["amount"].max()
print ("Highest sales:", max_sales)
# Out:
# Highest sales: 99.99

# %%
top_sales=df.sort_values(by="amount", ascending=False)
print(top_sales.head())
# Out:
#           first_name         last_name                       email  \
# 7249      Evan Mccoy  Stephen Thornton         carly46@example.org
# 4271  Derek Thompson    Dennis Jackson       wmitchell@example.com
# 6908  Anthony Wright         Amy Tyler       tiffany16@example.org
# 5527    Alexis Carey    Jeffrey Nelson      danielle23@example.org
# 3118    Taylor Downs      Allen Jordan  friedmancheryl@example.org
#
#       product_id  qty  amount invoice_date                      address  \
# 7249         167    4   99.99   18/11/1979    4750 David Inlet Apt. 315
# 4271         181    3   99.99   26/03/1985         25434 Barnett Summit
# 6908         157    8   99.99   16/08/2021               443 Welch Lane
# 5527         109    1   99.98   05/07/1992  466 William Ville Suite 114
# 3118         183    7   99.96   05/03/2016    168 Ford Square Suite 510
#
#                   city  stock_code                         job
# 7249   East Summerview    18891126             Psychotherapist
# ...
